# %%
import datapane as dp
import altair as alt
import pandas as pd
import random

# %% [markdown]
# ## Load the data
#
# Our data is in a CSV file, and our wrangling operations are offered by `pandas`, so let's [get our data into](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#sql-queries) a `DataFrame`.
#
# The first row contains column descriptions, in addition to the column headers, let's filter them out and show the result.

# %%
src_data = pd.read_csv("./kaggle_survey_2021_responses.csv.gz")
data = src_data.iloc[1:]
dp.DataTable(data.head())
# Out:
# /tmp/ipykernel_4909/64383188.py:1: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types. Specify dtype option on import or set low_memory=False.
#   src_data = pd.read_csv("./kaggle_survey_2021_responses.csv.gz")
# <style>
#   #dp-fde8602f4c214accb01db9b331bed332 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-fde8602f4c214accb01db9b331bed332" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;fde8602f4c214accb01db9b331bed332&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cDataTable type=\&quot;application/vnd.apache.arrow+binary\&quot; rows=\&quot;5\&quot; columns=\&quot;369\&quot; schema=\&quot;[]\&quot; src=\&quot;ref://8c486ae4d3\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;8c486ae4d3&quot;: {&quot;src&quot;: &quot;data:application/vnd.apache.arrow+binary;base64,...&quot;, &quot;hash&quot;: &quot;8c486ae4d3&quot;, &quot;size&quot;: 270928, &quot;mime&quot;: &quot;application/vnd.apache.arrow+binary&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-fde8602f4c214accb01db9b331bed332");
# </script>

# %% [markdown]
# Now let's move the descriptions to their own DataFrame and show them.

# %%
descriptions = src_data.iloc[0].to_frame()
dp.DataTable(descriptions)
# Out:
# /home/mandeep/Dev/projects/datapane-components/.venv/lib/python3.11/site-packages/datapane/common/df_processor.py:28: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(df.index, pd.Int64Index):
# <style>
#   #dp-b4f3b981656b4891b11b25b2ab18e170 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-b4f3b981656b4891b11b25b2ab18e170" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;b4f3b981656b4891b11b25b2ab18e170&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cDataTable type=\&quot;application/vnd.apache.arrow+binary\&quot; rows=\&quot;369\&quot; columns=\&quot;1\&quot; schema=\&quot;[]\&quot; src=\&quot;ref://0c203051e6\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;0c203051e6&quot;: {&quot;src&quot;: &quot;data:application/vnd.apache.arrow+binary;base64,...&quot;, &quot;hash&quot;: &quot;0c203051e6&quot;, &quot;size&quot;: 87536, &quot;mime&quot;: &quot;application/vnd.apache.arrow+binary&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-b4f3b981656b4891b11b25b2ab18e170");
# </script>

# %%
segment_mapping = {
    "Roles": "Q5",
    "Industry": "Q20",
    "DS Team Size": "Q22",
    "Primary Tool": "Q41",
}

# %% [markdown]
# ## Word cloud function

# %%
def word_cloud(df: pd.DataFrame) -> dp.Plot:
    words_and_counts = df.melt()["value"].dropna().value_counts()
    words_and_counts = pd.DataFrame(words_and_counts).rename_axis().reset_index()
    words_and_counts.columns = ["word", "count"]

    def shuffled_range(n):
        return random.sample(range(n), k=n)

    n = len(words_and_counts)
    x = shuffled_range(n)
    y = shuffled_range(n)

    word_cloud_data = words_and_counts.assign(x=x, y=y)

    base = (
        alt.Chart(word_cloud_data)
        .encode(x=alt.X("x:O", axis=None), y=alt.Y("y:O", axis=None))
        .configure(background="#eef2ff")
    )

    word_cloud = (
        base.mark_text(baseline="middle")
        .encode(
            text="word:N",
            color=alt.Color("count:Q", scale=alt.Scale(scheme="purpleblue")),
            size=alt.Size("count:Q", legend=None, scale=alt.Scale(range=[20, 50])),
        )
        .configure_view(strokeWidth=0)
    )

    return dp.Plot(word_cloud)

# %% [markdown]
# Test our word cloud on all the question 9 responses:

# %%
word_cloud(data.filter(like="Q9_Part"))
# Out:
# <style>
#   #dp-f4ee648dd8c14223a49846926fb0aed1 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-f4ee648dd8c14223a49846926fb0aed1" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;f4ee648dd8c14223a49846926fb0aed1&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://88c378b958\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;88c378b958&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;88c378b958&quot;, &quot;size&quot;: 1912, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-f4ee648dd8c14223a49846926fb0aed1");
# </script>

# %% [markdown]
# ## Plotting segments

# %%
def plot_segment_distribution(df: pd.DataFrame, segment_name: str) -> dp.Plot:
    segments = df[segment_mapping[segment_name]]
    counts = pd.DataFrame(segments.value_counts()).rename_axis().reset_index()
    counts.columns = [segment_name, "counts"]

    fig = (
        alt.Chart(counts)
        .mark_bar()
        .encode(
            x=alt.X(counts.columns[0], sort="-y", axis=alt.Axis(labelAngle=-45)),
            y="counts",
            color=alt.Color(segment_name, scale=alt.Scale(scheme="rainbow"), legend=None),
        )
    )

    return dp.Plot(fig)

# %% [markdown]
# Test plotting the distribution of the Roles segment

# %%
plot_segment_distribution(data, "Roles")
# Out:
# <style>
#   #dp-baab938f54d24573b048ddf6c6bdea87 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-baab938f54d24573b048ddf6c6bdea87" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;baab938f54d24573b048ddf6c6bdea87&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://5d359f516c\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;5d359f516c&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;5d359f516c&quot;, &quot;size&quot;: 1628, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-baab938f54d24573b048ddf6c6bdea87");
# </script>

# %% [markdown]
# ## Filtering with a form
#
# Let's allow our user to filter the survey data and generate a word cloud themselves.
#
# First, we'll look towards filtering by programming language. These are in columns with a `Q7_Part_` prefix.

# %%
programming_languages = data.filter(like="Q7_Part_").melt().dropna().drop_duplicates().reset_index(drop=True)

programming_languages = pd.concat(
    [
        programming_languages,
        pd.DataFrame([["*", "All"]], columns=programming_languages.columns),
    ]
)

dp.Table(programming_languages)
# Out:
# <style>
#   #dp-230ddd9bf90142939e63a148b1995d8d {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-230ddd9bf90142939e63a148b1995d8d" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;230ddd9bf90142939e63a148b1995d8d&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cTable type=\&quot;application/vnd.datapane.table+html\&quot; src=\&quot;ref://bef279830a\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;bef279830a&quot;: {&quot;src&quot;: &quot;data:application/vnd.datapane.table+html;base64,...&quot;, &quot;hash&quot;: &quot;bef279830a&quot;, &quot;size&quot;: 1664, &quot;mime&quot;: &quot;application/vnd.datapane.table+html&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-230ddd9bf90142939e63a148b1995d8d");
# </script>

# %% [markdown]
# ## Overall summary

# %%
stats_group = dp.Group(
    dp.BigNumber(heading="Participants", value=len(data)),
    dp.BigNumber(heading="Segments", value=len(segment_mapping)),
)

stats_group
# Out:
# <style>
#   #dp-9417fecc922346b0a262e55cea8d2acf {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js"
#   integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w=="
#   crossorigin="anonymous"
#   referrerpolicy="no-referrer"
# ></script>
# <iframe id="dp-9417fecc922346b0a262e55cea8d2acf" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.1/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = false;
#     window.dpReportId = &quot;9417fecc922346b0a262e55cea8d2acf&quot;;
#     window.dpAuthorId = &quot;780a1afbdb1241eeab14f6ed8c41bf32&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cGroup columns=\&quot;1\&quot; valign=\&quot;top\&quot;\u003e\u003cBigNumber heading=\&quot;Participants\&quot; value=\&quot;25973\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Segments\&quot; value=\&quot;4\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003c/Group\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.1/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&quot; integrity=&quot;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, "#dp-9417fecc922346b0a262e55cea8d2acf");
# </script>

# %%
def process(programming_language: str, choice: str) -> dp.Group:
    filtered_data = data

    if programming_language != "All":
        programming_language_column = programming_languages[
            programming_languages.value == programming_language
        ].variable.item()
        filtered_data = filtered_data[filtered_data[programming_language_column] == programming_language]

    segment_plots = dp.Group(
        blocks=[plot_segment_distribution(filtered_data, segment) for segment in segment_mapping.keys()]
    )

    choice_id_looking = {
        "What machine learning framework do you use?": "Q9",
        "What programming language do you use?": "Q7",
    }

    word_cloud_plot = word_cloud(filtered_data.filter(like=choice_id_looking[choice]))

    return dp.Group(
        f"## {choice}",
        word_cloud_plot,
        "## Breakdown by segment",
        segment_plots,
    )


form = dp.Form(
    on_submit=process,
    target="output",
    label="Filters",
    controls=[
        dp.Choice(
            "programming_language",
            label="Programming language",
            initial="All",
            options=list(programming_languages.value),
        ),
        dp.Choice(
            "choice",
            label="Word cloud: survey question",
            initial="What programming language do you use?",
            options=[
                "What machine learning framework do you use?",
                "What programming language do you use?",
            ],
        ),
    ],
)


v = dp.View(
    "# Kaggle Survey 2021",
    dp.Group(form, stats_group, columns=2),
    dp.Empty(name="output"),
)

# %%
dp.serve_app(v)
# Out:
# Running serve_app on a static report - do you want to use save_report or upload_report instead?
# Please install Jupyter Widgets for an improved experienced with apps in Notebook environments: https://ipywidgets.readthedocs.io/en/latest/user_install.html
# <p>Your app is running on: <a href="http://127.0.0.1:8080">http://127.0.0.1:8080</a></p><p>Use notebook ⏹ or 'Stop/Interrupt' button to halt.</p>
